# %%
import pandas as pd
from iertools.read import read_sql 
import numpy as np 
import matplotlib.pyplot as plt 
from dateutil.parser import parse 
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 1. Agrupa todos tus casos en un dataframe

# %% [markdown]
# # 2. Selecciona fines de semana de mes

# %% [markdown]
# # 3. Limpia datos (Tira el fin de semana 2006-06-25)

# %% [markdown]
# # 4. Calcula métricas

# %%
f = "../idf/ProyectoFinal5_EstrategiaPinturayReflectiva.sql"
tmp = read_sql(f, read= "data")
tmp.data
# Out:
# variable_name        CUBICULO:AFN Zone Infiltration Air Change Rate (ach)  \
# date
# 2006-05-03 00:00:00                                           0.390640
# 2006-05-03 00:10:00                                           0.183163
# 2006-05-03 00:20:00                                           0.269566
# 2006-05-03 00:30:00                                           0.138395
# 2006-05-03 00:40:00                                           0.169485
# ...                                                                ...
# 2006-06-24 23:10:00                                           0.109667
# 2006-06-24 23:20:00                                           0.060297
# 2006-06-24 23:30:00                                           0.048896
# 2006-06-24 23:40:00                                           0.176229
# 2006-06-24 23:50:00                                           0.386720
#
# variable_name        CUBOJR:Zone Thermal Comfort Fanger Model PMV ()  \
# date
# ...
